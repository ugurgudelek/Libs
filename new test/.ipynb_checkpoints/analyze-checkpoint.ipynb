# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
BASEPATH = "adana_azot_yeni"

# %%
def listdir(basepath):
    return [os.path.join(basepath, folder) for folder in os.listdir(basepath)]

# %%
samples_paths = listdir(BASEPATH)

# %%
sample_readings_paths = listdir(samples_paths[1])

# %%
def subplot25(sample_readings_paths):
    fig, axes = plt.subplots(2, 5, sharex=True, sharey=True)
    for ix, sample_path in enumerate(sample_readings_paths):
        df = pd.read_csv(sample_path)
        axes[ix//5,ix%5].plot(df['wavelengths'], df['intensities'])
    fig.suptitle(sample_path)

# %%
for sample_path in samples_paths:
    sample_readings_paths = listdir(sample_path)
    subplot25(sample_readings_paths)

# %%
from functools import partial
from scipy import signal

class Sample:
    def __init__(self, path):
        self.raw_readings = [pd.read_csv(os.path.join(path, reading_name)) 
                                     for reading_name in os.listdir(path)]
        
        self.reading = self.dataframes_average(self.raw_readings)
        self.plot = partial(self.subplot, [self.reading], 1, 1)
        
        self.reading = self.find_peaks(self.reading)
    
    @staticmethod
    def find_peaks(reading, inplace=False):
        if not inplace:
            reading = reading.copy()
        
        peak_interval = 1.
        wavelengths = reading['wavelengths'].values
        intensities = reading['intensities'].values
        
        wavelengths_range = wavelengths.max() - wavelengths.min()
        sampling_interval = wavelengths_range / wavelengths.shape[0]

        peak_ixs = signal.argrelmax(intensities,
                                    order=int(peak_interval / sampling_interval))[0]
        
        reading['is_peak'] = False
        reading.loc[peak_ixs, 'is_peak'] = True
        return reading
        
        
    @staticmethod
    def subplot(readings, row, col):
        fig, axes = plt.subplots(row, col, sharex=True, sharey=True, squeeze=False)
        for ix, reading in enumerate(readings):
            axes[ix//col,ix%col if col!=1 else 0].plot(reading['wavelengths'], reading['intensities'])

    
    @staticmethod
    def dataframes_average(dataframes):
        avg_df = dataframes[0].copy()
        for df in dataframes[1:]:
            avg_df += df
        return avg_df / dataframes.__len__()

# %%
s = Sample(path=samples_paths[1])

# %%
plt.figure(figsize=(20,10))
plt.plot(s.reading['intensities'])
peak_df = s.reading.loc[s.reading['is_peak'] == True, :]
plt.scatter(x=peak_df.index.values, y= peak_df['intensities'], c='r')

# %%
r
# Out:
#       intensities  wavelengths   peak
# 0       -9.063507   247.765520  False
# 1      -13.191757   247.841992  False
# 2      -22.376519   247.918457  False
# 3      -27.639404   247.994916  False
# 4      -23.614678   248.071369  False
# 5      -25.471967   248.147816  False
# 6      -23.304870   248.224256  False
# 7      -24.956432   248.300690  False
# 8      -20.931635   248.377118  False
# 9      -21.653763   248.453540  False
# 10     -14.017116   248.529956  False
# 11     -12.159718   248.606365  False
# 12      -8.650391   248.682768  False
# 13      -5.966981   248.759164  False
# 14       2.805888   248.835555  False
# 15       4.354310   248.911939  False
# 16      11.889247   248.988317  False
# 17      18.599142   249.064689  False
# 18      23.863800   249.141054  False
# 19      21.799131   249.217413  False
# 20      29.955145   249.293766  False
# 21      34.084540   249.370113  False
# 22      42.860796   249.446454  False
# 23      40.589111   249.522788  False
# 24      49.572292   249.599116  False
# 25      55.871160   249.675438  False
# 26      60.105150   249.751753  False
# 27      69.193830   249.828062   True
# 28      68.574251   249.904365  False
# 29      68.779988   249.980662  False
# ...           ...          ...    ...
# 4066    23.973232   601.403599   True
# 4067    18.396960   601.493788  False
# 4068    14.864454   601.583964  False
# 4069    20.104269   601.674129   True
# 4070    12.021908   601.764281  False
# 4071    14.180362   601.854420  False
# 4072     9.172703   601.944548  False
# 4073    14.413226   602.034663   True
# 4074     8.487074   602.124765  False
# 4075     5.867847   602.214855  False
# 4076    12.245950   602.304933  False
# 4077    12.247604   602.394998   True
# 4078     5.073237   602.485051  False
# 4079     5.867014   602.575092  False
# 4080     2.679398   602.665120  False
# 4081     6.781237   602.755136   True
# 4082     2.219288   602.845139  False
# 4083     3.821127   602.935130  False
# 4084    -3.019537   603.025109  False
# 4085     5.639492   603.115075   True
# 4086     4.387234   603.205029  False
# 4087     4.159459   603.294970  False
# 4088    -2.565240   603.384899  False
# 4089     1.994660   603.474816  False
# 4090    -0.625256   603.564720  False
# 4091    -3.821070   603.654612  False
# 4092     0.852608   603.744491   True
# 4093    -6.551162   603.834358  False
# 4094    -6.552836   603.924213  False
# 4095    -1.194159   604.014055  False
#
# [4096 rows x 3 columns]

# %%
s.plot()
